# %% [markdown]
# Step 1: Import of libraries

# %%
# Library for file manipulation
import pandas as pd

#Importing train_test_split for spliting dataset to Training & Testing
from sklearn.model_selection import train_test_split

# Importing  Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
# Importing  Logistic Regression Model
from sklearn.linear_model import LogisticRegression
# Importing  Decision Tree Model
from sklearn.tree import DecisionTreeClassifier
# Importing  Naive Bayes Model
from sklearn.naive_bayes import GaussianNB

#Importing Performance Metric(Accuracy)
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 2: Dataset

# %%
#Loading Dataset
df = pd.read_csv(r"/content/bot_detection_dataset_with_accuracy.csv")
df
# Out:
#           IP_Address  Mouse_Movement_Speed  Typing_Speed  Click_Patterns  \
# 0      57.12.140.125                   494           116             484
# 1       114.71.52.44                   742           141             511
# 2       216.16.15.47                   554            91             585
# 3     111.119.13.101                   404            75             598
# 4    214.112.229.142                   372            99             338
# ..               ...                   ...           ...             ...
# 995    209.185.54.79                   413            71             612
# 996  218.129.133.216                   672            97             524
# 997  187.141.203.104                   499           109             687
# 998   211.247.91.189                   631           111             694
# 999  247.129.157.176                   490            75             454
#
#      Initial_Interaction_Time  Scroll_Speed  Action_Count  Label
# ...

# %%
# Viewing first 5 data
df.head()
# Out:
#         IP_Address  Mouse_Movement_Speed  Typing_Speed  Click_Patterns  \
# 0    57.12.140.125                   494           116             484
# 1     114.71.52.44                   742           141             511
# 2     216.16.15.47                   554            91             585
# 3   111.119.13.101                   404            75             598
# 4  214.112.229.142                   372            99             338
#
#    Initial_Interaction_Time  Scroll_Speed  Action_Count  Label
# 0                      1294           304            17      0
# 1                      1806           320            12      1
# 2                      1747           357            10      0
# 3                      1552           385             7      0
# 4                      1089           380            12      0

# %%
# Viewing 5 latest data
df.tail()
# Out:
#           IP_Address  Mouse_Movement_Speed  Typing_Speed  Click_Patterns  \
# 995    209.185.54.79                   413            71             612
# 996  218.129.133.216                   672            97             524
# 997  187.141.203.104                   499           109             687
# 998   211.247.91.189                   631           111             694
# 999  247.129.157.176                   490            75             454
#
#      Initial_Interaction_Time  Scroll_Speed  Action_Count  Label
# 995                      1562           308             9      0
# 996                      1334           289            12      0
# 997                      1838           519            16      1
# 998                      1620           465            18      1
# 999                      1405           349            17      0

# %%
# Info data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   IP_Address                1000 non-null   object
#  1   Mouse_Movement_Speed      1000 non-null   int64
#  2   Typing_Speed              1000 non-null   int64
#  3   Click_Patterns            1000 non-null   int64
#  4   Initial_Interaction_Time  1000 non-null   int64
#  5   Scroll_Speed              1000 non-null   int64
#  6   Action_Count              1000 non-null   int64
#  7   Label                     1000 non-null   int64
# dtypes: int64(7), object(1)
# memory usage: 62.6+ KB

# %%
# Type data
df.dtypes
# Out:
# IP_Address                  object
# Mouse_Movement_Speed         int64
# Typing_Speed                 int64
# Click_Patterns               int64
# Initial_Interaction_Time     int64
# Scroll_Speed                 int64
# Action_Count                 int64
# Label                        int64
# dtype: object

# %%
# Viewing rows and columns
df.shape
# Out:
# (1000, 8)

# %%
#Description of Dataset
df.describe()
# Out:
#        Mouse_Movement_Speed  Typing_Speed  Click_Patterns  \
# count           1000.000000   1000.000000     1000.000000
# mean             514.421000    100.966000      550.565000
# std              109.421894     21.792149      101.713507
# min              181.000000     32.000000      235.000000
# 25%              438.000000     86.000000      483.000000
# 50%              513.500000    102.000000      548.500000
# 75%              593.000000    116.000000      623.250000
# max              860.000000    172.000000      948.000000
#
#        Initial_Interaction_Time  Scroll_Speed  Action_Count       Label
# count               1000.000000   1000.000000   1000.000000  1000.00000
# mean                1639.231000    379.330000     14.949000     0.51000
# std                  305.744595     69.549092      3.327984     0.50015
# min                  702.000000    161.000000      5.000000     0.00000
# 25%                 1434.000000    334.750000     13.000000     0.00000
# ...

# %% [markdown]
# Step 3: Data cleaning

# %%
print("Checking for missing values in each column:")
print(df.isnull().sum())
# Out:
# Checking for missing values in each column:
# IP_Address                  0
# Mouse_Movement_Speed        0
# Typing_Speed                0
# Click_Patterns              0
# Initial_Interaction_Time    0
# Scroll_Speed                0
# Action_Count                0
# Label                       0
# dtype: int64

# %%
# Remove columns that have any NaN value
df = df.dropna(axis=1)

# Check remaining columns after removal
print("Remaining columns after removing columns with NaN:")
print(df.isnull().sum())
# Out:
# Remaining columns after removing columns with NaN:
# IP_Address                  0
# Mouse_Movement_Speed        0
# Typing_Speed                0
# Click_Patterns              0
# Initial_Interaction_Time    0
# Scroll_Speed                0
# Action_Count                0
# Label                       0
# dtype: int64

# %% [markdown]
# Step 4: Data Preprocessing

# %%
df.columns
# Out:
# Index(['IP_Address', 'Mouse_Movement_Speed', 'Typing_Speed', 'Click_Patterns',
#        'Initial_Interaction_Time', 'Scroll_Speed', 'Action_Count', 'Label'],
#       dtype='object')

# %%
# Applying preprocessing to the original dataset
X = df.drop(columns=["IP_Address", "Label"])
y = df["Label"]# Target Variable

# %%
# Visualize rows and column x
X.shape
# Out:
# (1000, 6)

# %%
# Visualize rows and column y
y.shape
# Out:
# (1000,)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# %%
# Visualize training data
print("Rows and columns of training data X_train:", X_train.shape)
print("Rows and columns of training data y_train:", X_train.shape)
# Out:
# Rows and columns of training data X_train: (900, 6)
# Rows and columns of training data y_train: (900, 6)

# %% [markdown]
# Step 5: Training Models

# %%
#Models to be evaluated
models = [
    # Naive Bayes Model
    GaussianNB(),

    # Logistic regression model
    LogisticRegression(random_state=50, max_iter=1000),

    # Decision Tree Model
    DecisionTreeClassifier(random_state=42),

    # Random forest model
    RandomForestClassifier(n_estimators=100, random_state=42)
]

# %%
# Evaluate each model
for i, model in enumerate(models):
    model.fit(X_train, y_train)
    test_accuracy = accuracy_score(y_test, model.predict(X_test))
    print(f"Model {i+1}: {type(model).__name__}")
    print(f"Testing Accuracy: {test_accuracy}")
    print("-----------------")
# Out:
# Model 1: GaussianNB
# Testing Accuracy: 0.87
# -----------------
# Model 2: LogisticRegression
# Testing Accuracy: 0.87
# -----------------
# Model 3: DecisionTreeClassifier
# Testing Accuracy: 0.81
# -----------------
# Model 4: RandomForestClassifier
# Testing Accuracy: 0.89
# -----------------
